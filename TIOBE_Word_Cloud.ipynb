# %% [markdown]
# <a href="https://colab.research.google.com/github/eric999j/PILTest/blob/master/TIOBE_Word_Cloud.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !python3 -m pip install -q plotly
# !python3 -m pip install -q pandas

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
from google.colab import drive  
drive.mount('/content/gdrive')    
# %cd /content/gdrive/"My Drive"/"Colab Notebooks"
# Out:
# Mounted at /content/gdrive
# /content/gdrive/My Drive/Colab Notebooks

# %%
# !pwd
# Out:
# /content/gdrive/My Drive/Colab Notebooks

# %%
import requests
import re
import os
import csv
url = 'https://www.tiobe.com/tiobe-index/'
headers = {
 'user-agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_2) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/81.0.4044.113 Safari/537.36'
}
f = open('programming.csv', 'w', newline='')
writer = csv.DictWriter(f, ['Programming','Percent','Date'])
writer.writeheader()
response = requests.get(url, headers=headers)
html = response.text
result = ''.join(re.findall(r'series: (.*?)\}\);', html, re.DOTALL))
result = re.findall(r'({.*?})', result, re.DOTALL)
for item in result:
 name = ''.join(re.findall(r"{name : '(.*?)'", item, re.DOTALL))
 data = re.findall(r"\[Date.UTC(.*?)\]", item, re.DOTALL)
 for i in data:
  i = i.replace(' ', '')
  i = re.sub(r'[()]', '', i)
  value = i.split(',')[-1]
  time_list = i.split(',')[:3]
  time = ""
  for index, j in enumerate(time_list):
   if index !=0:
    if len(j) == 1:
     j = '0' + j
   if index == 0:
    time += j
   else:
    time += '-' + j
  temp = {
   'Programming': name,
   'Percent': value,
   'Date': time
  }
  writer.writerow(temp)
f.close()

# %%
import plotly.express as px
import pandas as pd
df = pd.read_csv('programming.csv')
fig = px.bar(df,
             y="Programming",
             x="Percent",
             animation_frame="Date",
             range_x=[0, df.Percent.max()],
             orientation='h',
             text='Percent',
             color="Programming")
fig.update_layout(width=500,
                  height=400,
                  xaxis_showgrid=False,
                  yaxis_showgrid=False,
                  showlegend=False)
fig.update_xaxes(title_text= "十年编程语言趋势图(微信订阅号：小猿学Python)")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="7523788b-356b-4d7a-ada5-eaae5192a99c" class="plotly-graph-div" style="height:400px; width:500px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("7523788b-356b-4d7a-ada5-eaae5192a99c")) {
#                     Plotly.newPlot(
#                         '7523788b-356b-4d7a-ada5-eaae5192a99c',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Programming=%{y}<br>Date=2001-05-30<br>Percent=%{text}", "legendgroup": "Programming=C", "marker": {"color": "#636efa"}, "name": "Programming=C", "offsetgroup": "Programming=C", "orientation": "h", "showlegend": true, "text": [20.24], "textposition": "auto", "type": "bar", "x": [20.24], "xaxis": "x", "y": ["C"], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Programming=%{y}<br>Date=2001-05-30<br>Percent=%{text}", "legendgroup": "Programming=Java", "marker": {"color": "#EF553B"}, "name": "Programming=Java", "offsetgroup": "Programming=Java", "orientation": "h", "showlegend": true, "text": [26.49], "textposition": "auto", "type": "bar", "x": [26.49], "xaxis": "x", "y": ["Java"], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Programming=%{y}<br>Date=2001-05-30<br>Percent=%{text}", "legendgroup": "Programming=Python", "marker": {"color": "#00cc96"}, "name": "Programming=Python", "offsetgroup": "Programming=Python", "orientation": "h", "showlegend": true, "text": [1.25], "textposition": "auto", "type": "bar", "x": [1.25], "xaxis": "x", "y": ["Python"], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Programming=%{y}<br>Date=2001-05-30<br>Percent=%{text}", "legendgroup": "Programming=C++", "marker": {"color": "#ab63fa"}, "name": "Programming=C++", "offsetgroup": "Programming=C++", "orientation": "h", "showlegend": true, "text": [14.2], "textposition": "auto", "type": "bar", "x": [14.2], "xaxis": "x", "y": ["C++"], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Programming=%{y}<br>Date=2001-05-30<br>Percent=%{text}", "legendgroup": "Programming=C#", "marker": {"color": "#FFA15A"}, "name": "Programming=C#", "offsetgroup": "Programming=C#", "orientation": "h", "showlegend": true, "text": [0.38], "textposition": "auto", "type": "bar", "x": [0.38], "xaxis": "x", "y": ["C#"], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Programming=%{y}<br>Date=2001-05-30<br>Percent=%{text}", "legendgroup": "Programming=JavaScript", "marker": {"color": "#FF6692"}, "name": "Programming=JavaScript", "offsetgroup": "Programming=JavaScript", "orientation": "h", "showlegend": true, "text": [1.55], "textposition": "auto", "type": "bar", "x": [1.55], "xaxis": "x", "y": ["JavaScript"], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Programming=%{y}<br>Date=2001-05-30<br>Percent=%{text}", "legendgroup": "Programming=PHP", "marker": {"color": "#B6E880"}, "name": "Programming=PHP", "offsetgroup": "Programming=PHP", "orientation": "h", "showlegend": true, "text": [1.9], "textposition": "auto", "type": "bar", "x": [1.9], "xaxis": "x", "y": ["PHP"], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Programming=%{y}<br>Date=2001-05-30<br>Percent=%{text}", "legendgroup": "Programming=SQL", "marker": {"color": "#FECB52"}, "name": "Programming=SQL", "offsetgroup": "Programming=SQL", "orientation": "h", "showlegend": true, "text": [2.96], "textposition": "auto", "type": "bar", "x": [2.96], "xaxis": "x", "y": ["SQL"], "yaxis": "y"}],
#                         {"barmode": "relative", "height": 400, "legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "showlegend": false, "sliders": [{"active": 0, "currentvalue": {"prefix": "Date="}, "len": 0.9, "pad": {"b": 10, "t": 60}, "steps": [{"args": [["2001-05-30"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "2001-05-30", "method": "animate"}, {"args": [["2001-06-30"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "2001-06-30", "method": "animate"}, {"args": [["2001-07-30"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "2001-07-30", "method": "animate"}, {"args": [["2001-08-28"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "2001-08-28", "method": "animate"}, {"args": [["2001-09-26"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "2001-09-26", "method": "animate"}, {"args": [["2001-10-28"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "2001-10-28", "method": "animate"}, {"args": [["2001-11-31"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "2001-11-31", "method": "animate"}, {"args": [["2002-00-30"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "2002-00-30", "method": "animate"}, {"args": [["2002-01-27"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "2002-01-27", "method": "animate"}, {"args": [["2002-02-29"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "2002-02-29", "method": "animate"}, {"args": [["2002-03-29"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "2002-03-29", "method": "animate"}, {"args": [["2002-04-29"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "2002-04-29", "method": "animate"}, {"args": [["2002-05-29"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "2002-05-29", "method": "animate"}, {"args": [["2002-06-31"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "2002-06-31", "method": "animate"}, {"args": [["2002-07-29"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "2002-07-29", "method": "animate"}, {"args": [["2002-08-29"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "2002-08-29", "method": "animate"}, {"args": [["2002-09-30"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "t
